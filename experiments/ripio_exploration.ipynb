# %% [markdown]
# # Exploration of the environment Pokemon Showdown

# %%
# Install requirements
# %pip install -r requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Starting the Pokemon Showdown server
#
# `node pokemon-showdown start --no-security`

# %%
# Run docker with server
# !docker compose -f ./docker/compose.yml up --build --detach
# Out:
# [+] Building 0.0s (0/1)
#  => [internal] load local bake definitions                                 0.0s
# [+] Building 0.1s (1/2)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 390B                                             0.0s
# [+] Building 0.3s (2/3)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 390B                                             0.0s
#  => [internal] load build definition from Dockerfile                       0.0s
#  => => transferring dockerfile: 945B                                       0.0s
#  => [internal] load metadata for docker.io/library/node:lts                0.2s
# [+] Building 0.4s (2/3)
#  => [internal] load local bake definitions                                 0.0s
#  => => reading from stdin 390B                                             0.0s
# ...

# %% [markdown]
# # Random battle

# %%
from poke_env import RandomPlayer
from poke_env.exceptions import ShowdownException

player_1 = RandomPlayer(battle_format="gen3randombattle")
player_2 = RandomPlayer(battle_format="gen3randombattle")

await player_1.battle_against(player_2, n_battles=100)


print(f"Player {player_1.username} won {player_1.n_won_battles} out of {player_1.n_finished_battles} played")
print(f"Player {player_2.username} won {player_2.n_won_battles} out of {player_2.n_finished_battles} played")

# Looping over battles
#for battle_tag, battle in player_1.battles.items():
#    print(battle_tag, battle.won)
# Out:
# 2025-06-14 18:11:03,289 - RandomPlayer 5 - WARNING - Unmanaged move message format received - cleaned up message ['', 'move', 'p2a: Politoed', 'Surf', 'p1a: Exeggutor', '[from]Sleep Talk'] in battle battle-gen3randombattle-131 turn 99
# 2025-06-14 18:11:03,291 - RandomPlayer 6 - WARNING - Unmanaged move message format received - cleaned up message ['', 'move', 'p2a: Politoed', 'Surf', 'p1a: Exeggutor', '[from]Sleep Talk'] in battle battle-gen3randombattle-131 turn 99
# 2025-06-14 18:11:03,412 - RandomPlayer 5 - WARNING - Unmanaged move message format received - cleaned up message ['', 'move', 'p2a: Regice', 'Thunderbolt', 'p1a: Exeggutor', '[from]Sleep Talk'] in battle battle-gen3randombattle-131 turn 121
# 2025-06-14 18:11:03,414 - RandomPlayer 6 - WARNING - Unmanaged move message format received - cleaned up message ['', 'move', 'p2a: Regice', 'Thunderbolt', 'p1a: Exeggutor', '[from]Sleep Talk'] in battle battle-gen3randombattle-131 turn 121
# ...
